# %%
Okienko Plain text jest używane z tego chat mówi tylko na surowe dane nie ma tutaj takich zmian graficznych jak w okienku markdown  :)

# %% [markdown]
# # Report: Analysis of Web-based Systems – Project 2
#
# **Prepared by:**
# * Adam Ćwikliński No. 273055
# * Jakub Kamiński No. 273107

# %%
- jak na razie nie wiem co trzeba zrobić ale jak chcesz to możemy wsm robić to tutaj.
w tym rodzaju plików ( żeby wyglądało to bardziej profesjonalnie i wgl xdd)

# %% [markdown]
# ## 1. Introduction and Project Objective
# The aim of this project is to analyze user behavior and the purchasing process for the **Google Merchandise Store** (https://shop.merch.google/) using a Google Analytics demo account. The analysis focuses on understanding customer acquisition, engagement, and the final conversion path.
#
# ## 2. Analysis Methodology
# The data used for this report covers the following periods:
# * **Full Day Analysis:** [Wpisz wybraną datę z marca/kwietnia 2026].
# * **Hourly Analysis:** [Wpisz wybraną godzinę, np. 5:00 PM - 6:00 PM UTC].
#
# ## 3. User Profiling
# ### 3.1 Geographic Location
# *Detailed analysis of where the users are coming from (Top Countries/Cities).*
#
# ### 3.2 Technologies Used
# * **Device Categories:** Mobile, Desktop, Tablet.
# * **Operating Systems & Browsers:** Analysis of the most popular platforms used by customers.
#
# ## 4. Customer Behavior Model Graph (CBMG)
# The purchasing process was analyzed based on the following lifecycle stages:
# 1. **Acquisition:** How users find the store.
# 2. **Engagement:** Interaction with store pages and events.
# 3. **Revenue Generation:** Final purchase and transaction details.
# 4. **Retention:** Returning user patterns.
#
# ## 5. Sales Performance and Engagement Metrics
# Based on the selected period, the following key performance indicators (KPIs) were identified:
#
# | Metric | Value |
# | :--- | :--- |
# | **Total Revenue** | [Wartość z GA] |
# | **Product Revenue** | [Wartość z GA] |
# | **Top Product (by Revenue)** | [Nazwa produktu] |
# | **Most Frequently Purchased** | [Nazwa produktu] |
#
# ## 6. Purchase Journey Analysis
# Using the **Purchase Journey** and **Path Exploration** reports, the following customer path was identified:
# * **Session Start** → **View Product** → **Add to Cart** → **Begin Checkout** → **Purchase**.
#
# *(Tutaj w raporcie należy wstawić zrzuty ekranu z Waszego konta GA prezentujące lejek sprzedażowy)*
#
# ## 7. Site Content and Traffic Analysis
# * **Pages with highest views:** [Lista stron].
# * **Events with highest frequency:** [Lista eventów, np. page_view, scroll, session_start].
# * **Active Users:** Maximum number of concurrent users during the peak hour.
#
# ## 8. Conclusions
# * [Wniosek 1: Np. Dominujący udział ruchu mobilnego sugeruje optymalizację pod smartfony.]
# * [Wniosek 2: Np. Największy spadek użytkowników następuje na etapie "Add to Cart".]
